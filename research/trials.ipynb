# %%
d={"key":"value","key1":"value1"}

# %%
d={"key":"value","key1":"value1"}

# %%
d['key']
# Out:
# 'value'

# %%
d.key
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 d.key
#
# AttributeError: 'dict' object has no attribute 'key'

# %%
from box import ConfigBox
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from box import ConfigBox
#
# ModuleNotFoundError: No module named 'box'

# %%
from box import Box
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from box import Box
#
# ModuleNotFoundError: No module named 'box'

# %%
import box
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 import box
#
# ModuleNotFoundError: No module named 'box'

# %%
from ensure import ensure_annotations

# %%
@ensure_annotations

def fun(x:int,y:int)->int:
    return x*y

# %%
fun(2,2)
# Out:
# 4

# %%
fun(2,'4')
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 fun(2,'4')
#
# File c:\Users\rajum\.conda\envs\chiken\Lib\site-packages\ensure\main.py:870, in WrappedFunctionReturn.__call__(self, *args, **kwargs)
#     868     if not isinstance(value, templ):
#     869         msg = "Argument {arg} of type {valt} to {f} " "does not match annotation type {t}"
# --> 870         raise EnsureError(msg.format(arg=arg, f=self.f, t=templ, valt=type(value)))
#     872 return_val = self.f(*args, **kwargs)
#     873 if not isinstance(return_val, self.return_templ):
#
# EnsureError: Argument y of type <class 'str'> to <function fun at 0x000001B7AFF25EE0> does not match annotation type <class 'int'>

# %%
from box import ConfigBox

# %%
d1=ConfigBox({'key':'value','key1':'value1'})

# %%
d1.key
# Out:
# 'value'

# %%
# !pip install ensure
# Out:
# Collecting ensure
#   Downloading ensure-1.0.4-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: six>=1.11.0 in c:\users\rajum\.conda\envs\chiken\lib\site-packages (from ensure) (1.17.0)
# Downloading ensure-1.0.4-py3-none-any.whl (15 kB)
# Installing collected packages: ensure
# Successfully installed ensure-1.0.4
